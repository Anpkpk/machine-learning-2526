# %% [markdown]
# # Phan I

# %% [markdown]
# ## Bai 1

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
lr = 0.1

# %% [markdown]
# a. $f(x) = x^2 - 4x + 4,\quad x_0 = 0$

# %%
def f(x):
    return x**2 - 4*x + 4

def df(x):
    return 2*x - 4

# %%
x = 0
for i in range(3):
    x = x - lr*df(x)
    print(f"Step {i+1}: x = {x}, f = {f(x)}")
# Out:
# Step 1: x = 0.4, f = 2.56
# Step 2: x = 0.7200000000000001, f = 1.6383999999999999
# Step 3: x = 0.976, f = 1.0485760000000002

# %% [markdown]
# b. $f(x) = x^4 - 3x^3 + 2,\quad x_0 = 1$

# %%
def f(x):
    return x**4 - 3*(x**3) + 2

def df(x):
    return 4*(x**3) - 9*x**2

# %%
x = 1
for i in range(3):
    x = x - lr*df(x)
    print(f"Step {i+1}: x = {x}, f = {f(x)}")
# Out:
# Step 1: x = 1.5, f = -3.0625
# Step 2: x = 2.175, f = -6.488515234375001
# Step 3: x = 2.3169187499999997, f = -6.495809719750227

# %% [markdown]
# c. $f(x) = \sin(x) + \frac{x^2}{10}, \quad x_0 = 2$

# %%
def f(x):
    return math.sin(x) + 1/10*(x**2)

def df(x):
    return math.cos(x) + x/5

# %%
x = 2
for i in range(3):
    x = x - lr*df(x)
    print(f"Step {i+1}: x = {x}, f = {f(x)}")
# Out:
# Step 1: x = 2.001614683654714, f = 1.3092704304435765
# Step 2: x = 2.003343842092813, f = 1.309239471525339
# Step 3: x = 2.0051954703876245, f = 1.3092039731672325

# %% [markdown]
# d. $f(x) = e^{0.5x} - 4x, \quad x_0 = 0$

# %%
def f(x):
    return math.exp(0.5*x) - 4*x

def df(x):
    return 0.5 * math.exp(0.5*x) - 4

# %%
x = 0
for i in range(3):
    x = x - lr*df(x)
    print(f"Step {i+1}: x = {x}, f = {f(x)}")
# Out:
# Step 1: x = 0.35000000000000003, f = -0.20875378338764206
# Step 2: x = 0.6904376891693822, f = -1.3494517968476625
# Step 3: x = 1.0198227411778888, f = -2.4141473570031318

# %% [markdown]
# ## Bai 2

# %%
def f(x):
    return x**2 - 6*x + 5

def df(x):
    return 2*x - 6

# %%
lr_1 = 0.01
lr_2 = 0.1
lr_3 = 0.5
lr_4 = 1.0

# %%
x = 0
x_arr_1 = []
for i in range(5):
    x_arr_1.append(x)
    x = x - lr_1*df(x)
    print(f"Step {i+1}: x = {x}")

x_arr_1 = np.array(x_arr_1)
y_1 = f(x_arr_1)
# Out:
# Step 1: x = 0.06
# Step 2: x = 0.11879999999999999
# Step 3: x = 0.176424
# Step 4: x = 0.23289552
# Step 5: x = 0.2882376096

# %%
x = 0
x_arr_2 = []
for i in range(5):
    x_arr_2.append(x)
    x = x - lr_2*df(x)
    print(f"Step {i+1}: x = {x}")

x_arr_2 = np.array(x_arr_2)
y_2 = f(x_arr_2)
# Out:
# Step 1: x = 0.6000000000000001
# Step 2: x = 1.08
# Step 3: x = 1.464
# Step 4: x = 1.7711999999999999
# Step 5: x = 2.01696

# %%
x = 0
x_arr_3 = []
for i in range(5):
    x_arr_3.append(x)
    x = x - lr_3*df(x)
    print(f"Step {i+1}: x = {x}")

x_arr_3 = np.array(x_arr_3)
y_3 = f(x_arr_3)
# Out:
# Step 1: x = 3.0
# Step 2: x = 3.0
# Step 3: x = 3.0
# Step 4: x = 3.0
# Step 5: x = 3.0

# %%
x = 0
x_arr_4 = []
for i in range(5):
    x_arr_4.append(x)
    x = x - lr_4*df(x)
    print(f"Step {i+1}: x = {x}")

x_arr_4 = np.array(x_arr_4)
y_4 = f(x_arr_4)
# Out:
# Step 1: x = 6.0
# Step 2: x = 0.0
# Step 3: x = 6.0
# Step 4: x = 0.0
# Step 5: x = 6.0

# %%
fig, axes = plt.subplots(1, 4, figsize=(15, 4))

axes[0].scatter(x_arr_1, y_1)
axes[0].plot(x_arr_1, y_1, color='blue', linestyle='-')
axes[0].set_xlabel("x")
axes[0].set_ylabel("y")
axes[0].set_title("lr = 0.01")


axes[1].scatter(x_arr_2, y_2)
axes[1].plot(x_arr_2, y_2, color='blue', linestyle='-')
axes[1].set_xlabel("x")
axes[1].set_ylabel("y")
axes[1].set_title("lr = 0.1")


axes[2].scatter(x_arr_3, y_3)
axes[2].plot(x_arr_3, y_3, color='blue', linestyle='-')
axes[2].set_xlabel("x")
axes[2].set_ylabel("y")
axes[2].set_title("lr = 0.5")

axes[3].scatter(x_arr_4, y_4)
axes[3].plot(x_arr_4, y_4, color='blue', linestyle='-')
axes[3].set_xlabel("x")
axes[3].set_ylabel("y")
axes[3].set_title("lr = 1")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Bai 3

# %% [markdown]
# $f(x, y) = (x−2)^2 + (y + 1)^2 + 3, \quad (x_0, y_0) = (0, 0), \quad \alpha = 0.1$

# %%
def f(x, y):
    return (x - 2)**2 + (y + 1)**2 + 3

def dfdx(x, y):
    return 2*(x - 2)

def dfdy(x, y):
    return 2*(y + 1)

# %%
lr = 0.1

x, y = 0.0, 0.0

for i in range(5):
    gx = dfdx(x, y)
    gy = dfdy(x, y)
    
    x = x - lr * gx
    y = y - lr * gy
    
    f_val = f(x, y)
    grad_norm = gx**2 + gy**2  
    
    print(f"Step {i+1}: (x, y) = ({x:.2f}, {y:.2f}), "
          f"f = {f_val:.2f}, "
          f"gradient norm = {grad_norm:.2f}")
# Out:
# Step 1: (x, y) = (0.40, -0.20), f = 6.20, gradient norm = 20.00
# Step 2: (x, y) = (0.72, -0.36), f = 5.05, gradient norm = 12.80
# Step 3: (x, y) = (0.98, -0.49), f = 4.31, gradient norm = 8.19
# Step 4: (x, y) = (1.18, -0.59), f = 3.84, gradient norm = 5.24
# Step 5: (x, y) = (1.34, -0.67), f = 3.54, gradient norm = 3.36

# %% [markdown]
# # Phan II

# %% [markdown]
# ## Bai 1

# %%
X = [i for i in range(1, 6)]
Y = [2, 4, 5, 4, 5]
X, Y
# Out:
# ([1, 2, 3, 4, 5], [2, 4, 5, 4, 5])

# %%
x_mean = 0
for i in X:
    x_mean += i

y_mean = 0
for i in Y:
    y_mean += i

x_mean = x_mean / len(X)
y_mean = y_mean / len(Y)

w_1 = 0
x_1 = 0
for i in range(len(X)):
   x_1 += (X[i] - x_mean)*(Y[i] - y_mean)

x_2 = 0
for x in X:
   x_2 += (x - x_mean)**2

w_1 = x_1/x_2 
w_0 = y_mean - w_1*x_mean

w_0, w_1
# Out:
# (2.2, 0.6)

# %%
y_6 = w_0 + w_1*6
y_6
# Out:
# 5.8

# %%
y_pred = []
for i in range(len(X)):
    y_pred.append(w_0 + w_1*X[i])

ss_res = 0
for i in range(len(Y)):
    ss_res += (Y[i] - y_pred[i])**2
mse = ss_res/len(y_pred)
mse
# Out:
# 0.47999999999999987

# %%
ss_tot = 0
for i in range(len(Y)):
    ss_tot += (Y[i] - y_mean)**2
ss_tot
# Out:
# 6.0

# %%
r_2 = 1 - ss_res/ss_tot
r_2
# Out:
# 0.6000000000000001

# %% [markdown]
# ## Bai 2

# %%
x_1 = np.array([1000, 1500, 2000, 1200, 1800])
x_1.resize(5, 1)

x_2 = np.array([2, 3, 4, 2, 3])
x_2.resize(5, 1)

y = np.array([200, 300, 400, 220, 350])
y.resize(5, 1)

# %%
x = np.hstack((x_1, x_2))

one = np.array([1, 1, 1, 1, 1])
one.resize(5, 1)

x = np.hstack((one, x))
x, y
# Out:
# (array([[   1, 1000,    2],
#         [   1, 1500,    3],
#         [   1, 2000,    4],
#         [   1, 1200,    2],
#         [   1, 1800,    3]]),
#  array([[200],
#         [300],
#         [400],
#         [220],
#         [350]]))

# %%
w = x.T.dot(x)
w = np.linalg.inv(w).dot(x.T).dot(y)
w
# Out:
# array([[-10.8411215 ],
#        [  0.15420561],
#        [ 26.26168224]])

# %%
x_test = np.array([1, 1600, 3])

y_pred = x_test.dot(w)
y_pred
# Out:
# array([314.6728972])

# %%
y_pred = x.dot(w)
mse = 1/len(y)*((y-y_pred)**2).sum()
mse
# Out:
# 17.943925233644766

# %%
ss_res = ((y-y_pred)**2).sum()
ss_tot = ((y-y_pred.mean())**2).sum()

r_2 = 1 - ss_res/ss_tot
r_2
# Out:
# 0.9968760575846719

# %% [markdown]
# ## Bai 3

# %%
import pandas as pd

# %%
df = pd.read_csv('advertising.csv')
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
x = df[['TV', 'Radio', 'Newspaper']]
y = df[['Sales']]

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].scatter(x['TV'], y)
axes[0].set_xlabel("TV")
axes[0].set_ylabel("Sales")
axes[0].set_title("TV - Sales")

# Radio
axes[1].scatter(x['Radio'], y)
axes[1].set_xlabel("Radio")
axes[1].set_title("Radio - Sales")

# Newspaper
axes[2].scatter(x['Newspaper'], y)
axes[2].set_xlabel("Newspaper")
axes[2].set_title("Newspaper - Sales")

plt.tight_layout()
plt.show()

# %%
X = x['TV']
# X = x['Newspaper']
# X = x['Radio']
X = X.to_numpy()

y = df['Sales']
y = y.to_numpy()

# %%
X_scaled = (X - X.min())/(X.max() - X.min())
y_scaled = (y - y.min())/(y.max() - y.min())

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (160,) (160,)

# %%
def predict(X, w0, w1):
    y_pred = w0 + w1*X
    return y_pred

# %%
def loss_function(y_true, y_pred):
    n = y_true.shape[0]
    s = np.sum((y_true - y_pred)**2)
    return (1/n) * s

# %%
def gradient(X, y, w0, w1):
    y_pred = predict(X, w0, w1)
    n = y_pred.shape[0]

    dw0 = -2/n * np.sum(y - y_pred)
    dw1 = -2/n * np.sum((y - y_pred)*X)

    return dw0, dw1

# %%
def fit(X, y, learning_rate=0.01, epochs=1000):
    losses = []
    w0, w1 = 0.0, 0.0

    for epoch in range(epochs):
        dw0, dw1 = gradient(X, y, w0, w1)

        w0 -= learning_rate*dw0
        w1 -= learning_rate*dw1

        y_pred = predict(X, w0, w1)
        loss = loss_function(y, y_pred)
        losses.append(loss)
        if epoch % 100 == 0:
            print(f'Epoch {epoch}, loss: {loss}')

    return w0, w1, losses

# %%
def plot_learning_curve(losses):
    plt.figure(figsize=(10, 6))
    plt.plot(range(len(losses)), losses, label='Training Loss (MSE)')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Learning Curve')
    plt.legend()
    plt.grid()
    plt.show()

# %%
w0, w1, losses = fit(X_train, y_train, learning_rate=0.05, epochs=1000)
plot_learning_curve(losses)
# Out:
# Epoch 0, loss: 0.2592078479037307
# Epoch 100, loss: 0.011564944969716405
# Epoch 200, loss: 0.008811907309127582
# Epoch 300, loss: 0.00804433826601417
# Epoch 400, loss: 0.007830333843024553
# Epoch 500, loss: 0.007770667688598429
# Epoch 600, loss: 0.007754032284833081
# Epoch 700, loss: 0.0077493942004601595
# Epoch 800, loss: 0.007748101065231597
# Epoch 900, loss: 0.007747740528728831

# %%
def evaluate(X, y, w0, w1):
    y_pred = predict(X, w0, w1)
    
    mse = (1 / len(X)) * np.sum((y_pred - y)**2)
    rmse = np.sqrt(mse)

    mae = (1 / len(X)) * np.sum(abs(y - y_pred))
    
    y_mean = np.sum(y) / len(y)
    SS_res = np.sum((y - y_pred)**2)
    SS_tot = np.sum((y - y_mean)**2)
    
    r2 = (1 - SS_res/SS_tot)
    return mse, rmse, mae, r2

# %%
y_pred = predict(X_test, w0, w1)
mse, rmse, mae, r2 = evaluate(X_test, y_test, w0, w1)
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'Mean Absolute Error: {mae}')
print(f'R-squared: {r2}')

plt.figure(figsize=(10, 6))
plt.scatter(X_test, y_test, color='b', label='Actual')

idx = np.argsort(X_test)        
X_sorted = X_test[idx]
y_pred_sorted = y_pred[idx]

plt.plot(X_sorted, y_pred_sorted, linewidth=3, color='r')
plt.title('Actual vs Predicted')
plt.xlabel('TV')
plt.ylabel('Sales')
plt.show()
# Out:
# Mean Squared Error: 0.0094570301812152
# Root Mean Squared Error: 0.09724726310398252
# Mean Absolute Error: 0.07678048320295172
# R-squared: 0.8025540323252959

# %%
class LinearRegression:
    def __init__(self, learning_rate=0.01, epochs=1000, bias=True):
        self.lr = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = bias

    def predict(self, X):
        y_pred = np.dot(X, self.weights.T)
        return y_pred

    def loss_function(self, y_true, y_pred):
        S = np.sum((y_true - y_pred) ** 2)
        mse = S/len(y_true)
        return mse

    def gradient(self, X, y):
        y_pred = self.predict(X)
        dw = -(1/len(y))*np.dot(X.T, (y - y_pred))
        return dw
    
    def fit(self, X, y):
        self.weights = np.zeros(X.shape[1])
        losses = []
        for epoch in range(self.epochs):
            dw = self.gradient(X, y)
            self.weights -= self.lr * dw
            y_pred = self.predict(X)
            loss = self.loss_function(y, y_pred)
            losses.append(loss)
            if epoch % 100 == 0:
                print(f'Epoch {epoch}, Loss {loss}')

        return losses

# %%
X = x
Y = y

X_scaled = (X - X.min())/(X.max() - X.min())
Y_scaled = (y - y.min())/(y.max() - y.min())

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, random_state=42)

# %%
model = LinearRegression(learning_rate=0.01, epochs=10000)
losses = model.fit(X_train, y_train)
plot_learning_curve(losses)
# Out:
# Epoch 0, Loss 0.3297711552202526
# Epoch 100, Loss 0.10365697417184098
# Epoch 200, Loss 0.03860195675405633
# Epoch 300, Loss 0.019418892330436244
# Epoch 400, Loss 0.013372427303971136
# Epoch 500, Loss 0.011148435828461896
# Epoch 600, Loss 0.010087496183707282
# Epoch 700, Loss 0.00942242162144043
# Epoch 800, Loss 0.00892528004729449
# Epoch 900, Loss 0.008522837862073616
# Epoch 1000, Loss 0.008187101368753131
# Epoch 1100, Loss 0.007904028400790145
# Epoch 1200, Loss 0.007664472706038508
# Epoch 1300, Loss 0.00746146885889695
# Epoch 1400, Loss 0.007289339967307179
# Epoch 1500, Loss 0.007143341669954281
# Epoch 1600, Loss 0.007019474178552414
# Epoch 1700, Loss 0.006914355363757538
# Epoch 1800, Loss 0.00682512245223296
# Epoch 1900, Loss 0.006749351394754979
# Epoch 2000, Loss 0.006684989334618268
# Epoch 2100, Loss 0.006630297639052691
# Epoch 2200, Loss 0.006583803723905079
# Epoch 2300, Loss 0.006544260280700503
# Epoch 2400, Loss 0.0065106107589987475
# ...

# %%
import numpy as np

def evaluate(y_true, y_pred):
    mse = np.mean((y_true - y_pred)**2)
    rmse = np.sqrt(mse)
    mae = np.mean(np.abs(y_true - y_pred))
    r2 = 1 - np.sum((y_true - y_pred)**2) / np.sum((y_true - np.mean(y_true))**2)
    return mse, rmse, mae, r2

# %%
y_pred = model.predict(X_test)
mse, rmse, mae, r2 = evaluate(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'Mean Absolute Error: {mae}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.0068333065271095365
# Root Mean Squared Error: 0.08266381631106524
# Mean Absolute Error: 0.064997548110812
# R-squared: 0.8573327150480083

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred)

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot([min_val, max_val], [min_val, max_val], linewidth=2)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %%
X_test.shape
# Out:
# (40, 3)

# %% [markdown]
# # Bai 4

# %%
class LinearRegression:
    def __init__(self, learning_rate=0.01, epochs=1000, bias=True, batch_size=32, shuffle=True):
        self.lr = learning_rate
        self.epochs = epochs
        self.weights = None
        self.bias = bias
        self.shuffle = shuffle
        self.batch_size = batch_size

    def predict(self, X):
        y_pred = np.dot(X, self.weights.T)
        return y_pred

    def loss_function(self, y_true, y_pred):
        S = np.sum((y_true - y_pred) ** 2)
        mse = S/len(y_true)
        return mse

    def gradient(self, X, y):
        y_pred = self.predict(X)
        dw = -(1/len(y))*np.dot(X.T, (y - y_pred))
        return dw
    
    def batch_generator(self, X, y):
        if self.shuffle:
            idx = np.random.permutation(len(y))
            X, y = X[idx], y[idx]

        for i in range(0, len(y), self.batch_size):
            yield X[i:i+self.batch_size], y[i:i+self.batch_size]


    def fit(self, X, y):
        self.weights = np.zeros(X.shape[1])
        losses = []
        for epoch in range(self.epochs):
            for X_batch, y_batch in self.batch_generator(X, y):
                dw = self.gradient(X_batch, y_batch)
                self.weights -= self.lr * dw

                y_pred = self.predict(X_batch)
                loss = self.loss_function(y_batch, y_pred)
                losses.append(loss)
            if epoch % 100 == 0:
                print(f'Epoch {epoch}, Loss {loss}')

        return losses

# %%
X = x
Y = y

X_scaled = (X - X.min())/(X.max() - X.min())
Y_scaled = (y - y.min())/(y.max() - y.min())
X_scaled = np.array(X_scaled)
Y_scaled = np.array(Y_scaled)

X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, random_state=42)

model = LinearRegression()
losses = model.fit(X_train, y_train)
plot_learning_curve(losses)
# Out:
# Epoch 0, Loss 0.30661813880416117
# Epoch 100, Loss 0.010020487713991463
# Epoch 200, Loss 0.00649747468254141
# Epoch 300, Loss 0.0040715744187880916
# Epoch 400, Loss 0.005649967346802747
# Epoch 500, Loss 0.0039931717263363515
# Epoch 600, Loss 0.006538437988198763
# Epoch 700, Loss 0.004541714793248579
# Epoch 800, Loss 0.007880157630576156
# Epoch 900, Loss 0.00743367700443647

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred)

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot([min_val, max_val], [min_val, max_val], linewidth=2)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()

# %%
model = LinearRegression(batch_size=1)
losses = model.fit(X_train, y_train)
plot_learning_curve(losses)
# Out:
# Epoch 0, Loss 0.03557311807299446
# Epoch 100, Loss 0.00020800693572096436
# Epoch 200, Loss 0.035209947381412865
# Epoch 300, Loss 0.00330829144991891
# Epoch 400, Loss 0.003109742882034342
# Epoch 500, Loss 0.003653243065160873
# Epoch 600, Loss 0.00011629605804147282
# Epoch 700, Loss 0.004840527678597702
# Epoch 800, Loss 0.004685966345066917
# Epoch 900, Loss 0.013748657041653876

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred)

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())

plt.plot([min_val, max_val], [min_val, max_val], linewidth=2)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")
plt.show()
